# %%
import pandas as pd
import numpy as np

# %%
# 버퍼 1km
df1 = pd.read_csv("1km.csv",encoding = "CP949")

# 버퍼 2km
df2 = pd.read_csv("2km.csv",encoding = "CP949")

# 버퍼 3km
df3 = pd.read_csv("3km.csv",encoding = "CP949")

# 버퍼 4km
df4 = pd.read_csv("4km.csv",encoding = "CP949")

# 버퍼 5km
df5 = pd.read_csv("5km.csv",encoding = "CP949")

# %% [markdown]
# # DataFrame 설정

# %%
df1_c = df1.loc[:, ['충전소','충전일수', '충전량_kWh', '도서관','민행기', '변압기', 
                    '전기차','경제인구수','주차면수'  ]]

df2_c = df2.loc[:, ['충전소','충전일수', '충전량_kWh', '도서관','민행기', '변압기', 
                    '전기차','경제인구수','주차면수'  ]]

df3_c = df3.loc[:, ['충전소','충전일수', '충전량_kWh', '도서관','민행기', '변압기', 
                    '전기차','경제인구수','주차면수'  ]]

df4_c = df4.loc[:, ['충전소','충전일수', '충전량_kWh', '도서관','민행기', '변압기', 
                    '전기차','경제인구수','주차면수'  ]]

df5_c = df5.loc[:, ['충전소','충전일수', '충전량_kWh', '도서관','민행기', '변압기', 
                    '전기차','경제인구수','주차면수'  ]]

# %%
df1_c['일당충전량'] = df1_c['충전량_kWh'] / df1_c['충전일수']
df2_c['일당충전량'] = df2_c['충전량_kWh'] / df2_c['충전일수']
df3_c['일당충전량'] = df3_c['충전량_kWh'] / df3_c['충전일수']
df4_c['일당충전량'] = df4_c['충전량_kWh'] / df4_c['충전일수']
df5_c['일당충전량'] = df5_c['충전량_kWh'] / df5_c['충전일수']

# %% [markdown]
# # 전기차와 충전량의 분산도

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings(action='ignore')

import matplotlib
from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')

# %%
tot_li = [df1_c, df2_c, df3_c, df4_c, df5_c]

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data=iris)
plt.suptitle("꽃받침의 길이와 넓이의 Joint Plot", y=1.02)
plt.show()

# %%
for i in range(len(tot_li)) :
    sns.jointplot(x = '충전량_kWh', y = '전기차', data = tot_li[i] )
    plt.title('버퍼'+ str(i+1)+ 'km 내의 '+ "총충전량과 전기차 분산도\n\n", fontsize = 30)
    plt.show()

# %%
for i in range(len(tot_li)) :
    sns.jointplot(x = '일당충전량', y = '전기차', data = tot_li[i] )
    plt.title('버퍼'+ str(i+1)+ 'km 내의 '+ "일당충전량과 전기차 분산도\n\n", fontsize = 30)
    plt.show()

# %% [markdown]
# # 변수들 상관분석

# %%
df_cor1 = df1_c.corr()
df_cor2 = df2_c.corr()
df_cor3 = df3_c.corr()
df_cor4 = df4_c.corr()
df_cor5 = df5_c.corr()

# %%
df_cor1
# Out:
#              충전일수   충전량_kWh       도서관       민행기       변압기       전기차     경제인구수  \
# 충전일수     1.000000  0.842862  0.005118  0.160596  0.158805  0.189200  0.201356
# 충전량_kWh  0.842862  1.000000  0.029125  0.131326  0.145507  0.241385  0.206414
# 도서관      0.005118  0.029125  1.000000  0.216720  0.200003  0.209639  0.189805
# 민행기      0.160596  0.131326  0.216720  1.000000  0.608197  0.539091  0.743591
# 변압기      0.158805  0.145507  0.200003  0.608197  1.000000  0.388423  0.816470
# 전기차      0.189200  0.241385  0.209639  0.539091  0.388423  1.000000  0.606794
# 경제인구수    0.201356  0.206414  0.189805  0.743591  0.816470  0.606794  1.000000
# 주차면수     0.027299  0.027875 -0.022205  0.212477  0.234331  0.291726  0.282242
# 일당충전량    0.534958  0.854195  0.116103  0.104601  0.101512  0.258593  0.185474
#
#              주차면수     일당충전량
# 충전일수     0.027299  0.534958
# 충전량_kWh  0.027875  0.854195
# 도서관     -0.022205  0.116103
# 민행기      0.212477  0.104601
# 변압기      0.234331  0.101512
# ...

# %%
df_cor2
# Out:
#              충전일수   충전량_kWh       도서관       민행기       변압기       전기차     경제인구수  \
# 충전일수     1.000000  0.842
# Out:
#              충전일수   충전량_kWh       도서관       민행기       변압기       전기차     경제인구수  \
# 충전일수     1.000000  0.842862 -0.034738 -0.007146  0.027687  0.069193  0.009484
# 충전량_kWh  0.842862  1.000000 -0.013480  0.014237  0.086033  0.153493  0.040684
# 도서관     -0.034738 -0.013480  1.000000  0.739009  0.790675  0.700294  0.722950
# 민행기     -0.007146  0.014237  0.739009  1.000000  0.958265  0.866797  0.980824
# 변압기      0.027687  0.086033  0.790675  0.958265  1.000000  0.894209  0.938105
# 전기차      0.069193  0.153493  0.700294  0.866797  0.894209  1.000000  0.870626
# 경제인구수    0.009484  0.040684  0.722950  0.980824  0.938105  0.870626  1.000000
# 주차면수     0.157763  0.182228  0.282314  0.682568  0.631130  0.789685  0.710036
# 일당충전량    0.534958  0.854195  0.012482  0.027236  0.097451  0.192902  0.060004
#
#              주차면수     일당충전량
# 충전일수     0.157763  0.534958
# 충전량_kWh  0.182228  0.854195
# 도서관      0.282314  0.012482
# 민행기      0.682568  0.027236
# 변압기      0.631130  0.097451
# ...

# %%
# 충전량_kWh, 일당충전량과 전기차 상관관계
df_cor = pd.DataFrame(([[df_cor1.loc['충전량_kWh', '전기차'], df_cor1.loc['일당충전량', '전기차']],
                       [df_cor2.loc['충전량_kWh', '전기차'], df_cor2.loc['일당충전량', '전기차']],
                       [df_cor3.loc['충전량_kWh', '전기차'], df_cor3.loc['일당충전량', '전기차']]
                       ,[df_cor4.loc['충전량_kWh', '전기차'], df_cor4.loc['일당충전량', '전기차']]
                       ,[df_cor5.loc['충전량_kWh', '전기차'], df_cor5.loc['일당충전량', '전기차']]]), columns = ['총충전량과 전기차 상관관계',
                                                                                                  '일당충전량과 전기차 상관관계'])
df_cor.index = ['1km','2km','3km', '4km', '5km']
df_cor
# Out:
#      총충전량과 전기차 상관관계  일당충전량과 전기차 상관관계
# 1km        0.241385         0.258593
# 2km        0.282420         0.286132
# 3km        0.206437         0.226032
# 4km        0.168001         0.200234
# 5km        0.153493         0.192902

# %% [markdown]
# # => 버퍼 2km가 가장 큰 상관관계를 갖습니다.
# # 따라서 버퍼 2km내에 충전량과 각 변수들 간의 상관관계를 구하고 그것을
# # 가중치로 사용!

# %%
df_cor2
# Out:
#              충전일수   충전량_kWh       도서관       민행기       변압기       전기차     경제인구수  \
# 충전일수     1.000000  0.842862  0.051686  0.165138  0.143365  0.216555  0.152605
# 충전량_kWh  0.842862  1.000000  0.085201  0.155511  0.187023  0.282420  0.158872
# 도서관      0.051686  0.085201  1.000000  0.450046  0.434632  0.394660  0.347180
# 민행기      0.165138  0.155511  0.450046  1.000000  0.857010  0.698097  0.892023
# 변압기      0.143365  0.187023  0.434632  0.857010  1.000000  0.629277  0.843638
# 전기차      0.216555  0.282420  0.394660  0.698097  0.629277  1.000000  0.711136
# 경제인구수    0.152605  0.158872  0.347180  0.892023  0.843638  0.711136  1.000000
# 주차면수     0.030558  0.036280  0.035788  0.374431  0.479244  0.415076  0.488578
# 일당충전량    0.534958  0.854195  0.096654  0.129368  0.161339  0.286132  0.140785
#
#              주차면수     일당충전량
# 충전일수     0.030558  0.534958
# 충전량_kWh  0.036280  0.854195
# 도서관      0.035788  0.096654
# 민행기      0.374431  0.129368
# 변압기      0.479244  0.161339
# ...

# %%
df2_2 = pd.read_csv("인천시_2km_충도민변전인주공음.csv", encoding = "CP949")
df2_2
# Out:
#                            충전소   충전량_kWh  충전일수  \
# 0             G-Tower(경제자유구역청)  30259.44   408
# 1                       LH인천본부  63815.83   612
# 2   ㈜현대자동차 블루핸즈 서인천 서비스 주차장 입구  10538.65   375
# 3                  가좌2동 행정복지센터   7387.11   196
# 4                    갈산역 공영주차장   3879.41   131
# 5                         강화군청  29291.07   517
# 6                         강화지사  10877.10   342
# 7                 강화풍물시장 공영주차장  27766.94   597
# 8                     검단2공영주차장  44358.60   630
# 9                  계산1택지 공영주차장  27959.93   606
# 10                   계양구 공영주차장  26312.12   579
# 11                        계양구청  37413.06   482
# 12                       남동복지관   6835.96   136
# 13                       남인천지사  54738.75   604
# 14                  늘솔길공원 3주차장   9586.64   214
# 15                   덕산국민여가캠핑장   5476.50   202
# 16                도원역 부근 공영주차장  41758.46   637
# 17                  동구청앞 공영주차장   5429.37   175
# 18                    롯데마트 검단점  28768.72   499
# ...

# %%
df2_2_c = df2_2.loc[:, ['충전소','충전일수', '충전량_kWh', '도서관','민행기', '변압기', 
                    '전기차','경제인구수','주차면수', '공원', '음식점'  ]]
df2_2_c['일당충전량'] = df2_2_c['충전량_kWh'] / df2_2_c['충전일수']
df2_2_c
# Out:
#                            충전소  충전일수   충전량_kWh  도서관  민행기   변압기  전기차     경제인구수  \
# 0             G-Tower(경제자유구역청)   408  30259.44    3   20   272  124   58789.0
# 1                       LH인천본부   612  63815.83    4   31  1595   81   69330.0
# 2   ㈜현대자동차 블루핸즈 서인천 서비스 주차장 입구   375  10538.65    5   17   376   54   54392.0
# 3                  가좌2동 행정복지센터   196   7387.11   13   39  1022   85  103367.0
# 4                    갈산역 공영주차장   131   3879.41    6   72  1438  150  265372.0
# 5                         강화군청   517  29291.07    1   18   137   16   13840.0
# 6                         강화지사   342  10877.10    1   14   138   17   13732.0
# 7                 강화풍물시장 공영주차장   597  27766.94    1   17   145   20   14687.0
# 8                     검단2공영주차장   630  44358.60    9   17   427   36   69679.0
# 9                  계산1택지 공영주차장   606  27959.93    2   59   886  114  179417.0
# 10                   계양구 공영주차장   579  26312.12    5   72  1360  135  237835.0
# ...

# %% [markdown]
# ## 공원, 음식점 추가해서 상관분석

# %%
df2_2_cor = df2_2_c.corr()
df2_2_cor
# Out:
#              충전일수   충전량_kWh       도서관       민행기       변압기       전기차     경제인구수  \
# 충전일수     1.000000  0.842862  0.051686  0.165138  0.143365  0.216555  0.152605
# 충전량_kWh  0.842862  1.000000  0.085201  0.155511  0.187023  0.282420  0.158872
# 도서관      0.051686  0.085201  1.000000  0.450046  0.434632  0.394660  0.347180
# 민행기      0.165138  0.155511  0.450046  1.000000  0.857010  0.698097  0.892023
# 변압기      0.143365  0.187023  0.434632  0.857010  1.000000  0.629277  0.843638
# 전기차      0.216555  0.282420  0.394660  0.698097  0.629277  1.000000  0.711136
# 경제인구수    0.152605  0.158872  0.347180  0.892023  0.843638  0.711136  1.000000
# 주차면수     0.030558  0.036280  0.035788  0.374431  0.479244  0.415076  0.488578
# 공원       0.015748 -0.026560  0.286185  0.608656  0.585569  0.513573  0.737941
# 음식점      0.179792  0.209307  0.403480  0.925537  0.831635  0.629609  0.913803
# 일당충전량    0.534958  0.854195  0.096654  0.129368  0.161339  0.286132  0.140785
#
# ...
