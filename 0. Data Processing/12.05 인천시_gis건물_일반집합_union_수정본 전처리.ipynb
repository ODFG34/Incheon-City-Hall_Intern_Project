# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("19.12.05_인천시_gis건물_일반집합_union.csv", encoding = "CP949")
df.head(1)
# Out:
#                       SikNumber UsageCode UsageName  ParkArNum
# 0  1995164410394391683600000000     08000      운수시설         58

# %%
df['UsageName'].unique()
# Out:
# array(['운수시설', '교육연구시설', '판매시설', '제2종근린생활시설', '자동차관련시설', '업무시설', '공장',
#        '종교시설', '제1종근린생활시설', '방송통신시설', '교육연구및복지시설', '분뇨.쓰레기처리시설', '운동시설',
#        '의료시설', '문화및집회시설', '창고시설', '근린생활시설', '위험물저장및처리시설', '숙박시설', '발전시설',
#        '관광휴게시설', '노유자시설', '공동주택', '장례식장', '동.식물 관련시설', '단독주택', '판매및영업시설'],
#       dtype=object)

# %%
'운수시설', '교육연구시설', '판매시설', '제2종근린생활시설', '자동차관련시설', '업무시설', '공장',
'종교시설', '제1종근린생활시설', '방송통신시설', '교육연구및복지시설', '분뇨.쓰레기처리시설', '운동시설',
'의료시설', '문화및집회시설', '창고시설', '근린생활시설', '위험물저장및처리시설', '숙박시설', '발전시설',
'관광휴게시설', '노유자시설', '공동주택', '장례식장', '동.식물 관련시설', '단독주택', '판매및영업시설'

# %%
pd.DataFrame(list(df['UsageName'].unique()))
# Out:
#              0
# 0         운수시설
# 1       교육연구시설
# 2         판매시설
# 3    제2종근린생활시설
# 4      자동차관련시설
# 5         업무시설
# 6           공장
# 7         종교시설
# 8    제1종근린생활시설
# 9       방송통신시설
# 10   교육연구및복지시설
# 11  분뇨.쓰레기처리시설
# 12        운동시설
# 13        의료시설
# 14     문화및집회시설
# 15        창고시설
# 16      근린생활시설
# 17  위험물저장및처리시설
# 18        숙박시설
# 19        발전시설
# 20      관광휴게시설
# 21       노유자시설
# 22        공동주택
# 23        장례식장
# 24   동.식물 관련시설
# 25        단독주택
# 26     판매및영업시설
